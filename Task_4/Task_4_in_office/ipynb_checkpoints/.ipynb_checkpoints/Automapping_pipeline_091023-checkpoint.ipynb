# %%
import re
import time
import numpy as np
import pandas as pd
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sqlalchemy import create_engine

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
#   Downloading https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz (15.9 MB)
#      ---------------------------------------- 15.9/15.9 MB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: spacy<3.5.0,>=3.4.1 in c:\users\1\anaconda3\lib\site-packages (from en-core-sci-sm==0.5.1) (3.4.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (8.1.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.0.5)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.10.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.28.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (5.2.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.7.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.10.13)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.4.8)
# Requirement already satisfied: setuptools in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (63.4.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.21.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.0.12)
# Requirement already satisfied: jinja2 in c:\users\1\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\1\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\1\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (4.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\1\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\1\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\1\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\1\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\1\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\1\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.7.11)
# Requirement already satisfied: colorama in c:\users\1\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\1\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\1\anaconda3\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.1)
# Building wheels for collected packages: en-core-sci-sm
#   Building wheel for en-core-sci-sm (setup.py): started
#   Building wheel for en-core-sci-sm (setup.py): finished with status 'done'
#   Created wheel for en-core-sci-sm: filename=en_core_sci_sm-0.5.1-py3-none-any.whl size=15870856 sha256=27b867231f2beec10490ad620d81846f6169add8abb370f1ea8b161e6d7b56c9
#   Stored in directory: c:\users\1\appdata\local\pip\cache\wheels\f5\2e\39\9c9d425a1d34c06409420f7c65c5e10a56f7b149a3c37cdfa6
# Successfully built en-core-sci-sm
# Installing collected packages: en-core-sci-sm
# Successfully installed en-core-sci-sm-0.5.1

# %%
# Загрузка модели для английского языка
nlp = spacy.load("en_core_sci_sm")

# %%
# Read the CSV files into dataframes
voc2_df = pd.read_csv('SNOMED_OMOP_vocabulary_preprocessed.csv')
voc1_df = pd.read_csv('etl_test_061023.csv')
voc1_df=voc1_df[:500]

# %%
voc1_df
# Out:
#                                     concept_name  concept_id  \
# 0                              Excision of hymen           0
# 1                     OTHER: JVD, RASH, ERYTHEMA           0
# 2                                   HIP FRACTURE           0
# 3                                     Osmolality           0
# 4                Liver disorder in pregnancy NOS           0
# ..                                           ...         ...
# 495                    Candida angular cheilitis           0
# 496  Superficial partial thickness burn of ankle           0
# 497            Spastic hemiplegic cerebral palsy           0
# 498                          Leptospira serology           0
# 499           Obstetric umbilical artery Doppler           0
#
#      target_concept_id
# 0              4248130
# 1               137193
# 2             45763653
# 3              4237146
# 4               194699
# ..                 ...
# 495            4150302
# 496            4057789
# 497           44806793
# 498           37392837
# 499            4145534
#
# [500 rows x 3 columns]

# %%
voc2_df
# Out:
#         concept_id                                       concept_name  \
# 0         36684768                    Drusen of bilateral optic discs
# 1         37110249     Microvascular embolism of arteriole (disorder)
# 2          4220821                                   Bronzed diabetes
# 3          4120412                              Level of psychoticism
# 4          4002835                             Bruising of oropharynx
# ...            ...                                                ...
# 564483     4036092                     ROM - Range of motion activity
# 564484    37309624  Low back pain co-occurrent with left side scia...
# 564485     4006806                           Miscarriage with uraemia
# 564486     4238036                                 Urological fistula
# 564487     4318113  Carbon monoxide poisoning from faulty furnace ...
#
#                                    concept_name_processed
# 0               ['drusen', 'bilateral', 'optic', 'discs']
# 1       ['microvascular', 'embolism', 'arteriole', 'di...
# 2                                  ['bronzed', 'diabete']
# 3                               ['level', 'psychoticism']
# 4                                ['bruise', 'oropharynx']
# ...                                                   ...
# 564483             ['rom', 'range', 'motion', 'activity']
# 564484  ['low', 'back', 'pain', 'cooccurrent', 'leave'...
# 564485                         ['miscarriage', 'uraemia']
# 564486                          ['urological', 'fistula']
# 564487  ['carbon', 'monoxide', 'poisoning', 'faulty', ...
#
# [564488 rows x 3 columns]

# %%
# # words to remove from strings
# stop_words = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd",
#              'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers',
#              'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what',
#              'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were',
#              'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the',
#              'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about',
#              'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from',
#              'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
#              'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other',
#              'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can',
#              'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain',
#              'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn',
#              "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn',
#              "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't",
#              'wouldn', "wouldn't",
#               # don't care  about right and left most of the time
#              #'right','left']

# %%
stop_words = ['noc', 'nos', '[d]', 'unknown_unit', '|', 'see comment', 'due', 'nec', 'unspecified', '[v]', '(see comments)',
              '(disorder)', '(procedure)', '(finding)']
# ignores weird symbols
voc1_df['concept_name_processed'] = voc1_df['concept_name'].apply(lambda x: re.sub(r"\s+", " ", str(x).encode('ascii', 'ignore').decode()) if isinstance(x, str) else str(x))
#voc2_df['concept_name_processed'] = voc2_df['concept_name'].apply(lambda x: re.sub(r"\s+", " ", str(x.encode('ascii', 'ignore').decode())))
# Remove punctuation, digits etc
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].map(lambda x: re.sub('[,\.!;?)%(\'\":\-]', '', x))
#voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].map(lambda x: re.sub('[,\.!;?)%(\'\":\-]', '', x))
# Convert the titles to lowercase
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].map(lambda x: x.lower())
#voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].map(lambda x: x.lower())
# Remove stopwords
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
#voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
voc1_df.head(5)
# Out:
#                       concept_name  concept_id  target_concept_id  \
# 0                Excision of hymen           0            4248130
# 1       OTHER: JVD, RASH, ERYTHEMA           0             137193
# 2                     HIP FRACTURE           0           45763653
# 3                       Osmolality           0            4237146
# 4  Liver disorder in pregnancy NOS           0             194699
#
#         concept_name_processed
# 0            excision of hymen
# 1      other jvd rash erythema
# 2                 hip fracture
# 3                   osmolality
# 4  liver disorder in pregnancy

# %%
voc2_df.head(5)
# Out:
#    concept_id                                    concept_name  \
# 0    36684768                 Drusen of bilateral optic discs
# 1    37110249  Microvascular embolism of arteriole (disorder)
# 2     4220821                                Bronzed diabetes
# 3     4120412                           Level of psychoticism
# 4     4002835                          Bruising of oropharynx
#
#                               concept_name_processed
# 0          ['drusen', 'bilateral', 'optic', 'discs']
# 1  ['microvascular', 'embolism', 'arteriole', 'di...
# 2                             ['bronzed', 'diabete']
# 3                          ['level', 'psychoticism']
# 4                           ['bruise', 'oropharynx']

# %%
def tokenize_with_spacy(text):
    doc = nlp(text)
    tokens = [token.text for token in doc if not token.is_punct and not token.is_space]
    return tokens

start_time = time.time()

voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(tokenize_with_spacy)
#voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(tokenize_with_spacy)

elapsed_time = (time.time() - start_time)/60
print(f"Total elapsed time for tokenization: {elapsed_time:.1f} minutes")


def lemmatize_with_spacy(text):
    doc = nlp(text)
    lemmatized_tokens = [token.lemma_ for token in doc]
    return lemmatized_tokens

start_time = time.time()

# Применение функции к вашему столбцу
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: lemmatize_with_spacy(' '.join(x)))
#voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: lemmatize_with_spacy(' '.join(x)))

elapsed_time = (time.time() - start_time)/60
print(f"Total elapsed time for lemmatization: {elapsed_time:.1f} minutes")
# Out:
# Total elapsed time for tokenization: 0.0 minutes
# Total elapsed time for lemmatization: 0.0 minutes

# %%
voc1_df.head()
# Out:
#                       concept_name  concept_id  target_concept_id  \
# 0                Excision of hymen           0            4248130
# 1       OTHER: JVD, RASH, ERYTHEMA           0             137193
# 2                     HIP FRACTURE           0           45763653
# 3                       Osmolality           0            4237146
# 4  Liver disorder in pregnancy NOS           0             194699
#
#              concept_name_processed
# 0             [excision, of, hyman]
# 1      [other, jvd, rash, erythema]
# 2                   [hip, fracture]
# 3                      [osmolality]
# 4  [liver, disorder, in, pregnancy]

# %%
voc2_df.head()
# Out:
#    concept_id                                    concept_name  \
# 0    36684768                 Drusen of bilateral optic discs
# 1    37110249  Microvascular embolism of arteriole (disorder)
# 2     4220821                                Bronzed diabetes
# 3     4120412                           Level of psychoticism
# 4     4002835                          Bruising of oropharynx
#
#                               concept_name_processed
# 0          ['drusen', 'bilateral', 'optic', 'discs']
# 1  ['microvascular', 'embolism', 'arteriole', 'di...
# 2                             ['bronzed', 'diabete']
# 3                          ['level', 'psychoticism']
# 4                           ['bruise', 'oropharynx']

# %%
# Save previously prepared vocabulary for future use
# voc2_df.to_csv('/content/drive/MyDrive/SNOMED_OMOP_vocabulary_preprocessed.csv', index=False)

# %% [markdown]
# # TfIDF

# %%
# Preprocess and compute the TF-IDF document-term matrix for the snomed concepts
voc2_docs = voc2_df['concept_name_processed'].apply(lambda x: ''.join(x)).tolist()
tfidf_vectorizer = TfidfVectorizer()
voc2_dtm = tfidf_vectorizer.fit_transform(voc2_docs)

# Calculate cosine similarities and find 5 most similar snomed concepts for each meddra concept
results = []

batch_size = 10
num_top_matches = 5

start_time = time.time()
processed_count = 0

for voc1_index, voc1_row in voc1_df.iterrows():
    voc1_tokens = voc1_row['concept_name_processed']
    voc1_name = voc1_row['concept_name']
    voc1_concept_id = voc1_row['concept_id']

    voc1_text = ' '.join(voc1_tokens)
    voc1_dtm = tfidf_vectorizer.transform([voc1_text])

    similarities = cosine_similarity(voc1_dtm, voc2_dtm)[0]

    # Find indices of 5 most similar voc2 (SNOMED and etc.) concepts
    top_indices = np.argsort(similarities)[-num_top_matches:][::-1]

    for max_index in top_indices:
        voc2_concept_id = voc2_df.loc[max_index, 'concept_id']
        voc2_name = voc2_df.loc[max_index, 'concept_name']
        similarity = similarities[max_index]

        # Add a separate line of information to the results
        results.append((voc1_name, voc1_concept_id, voc2_concept_id, voc2_name, similarity))

    processed_count += 1
    if processed_count % batch_size == 0:
        elapsed_time = (time.time() - start_time) / 60
        print(f"Processed {processed_count} concepts in {elapsed_time:.1f} minutes")

# Sort the results by similarity in descending order
results.sort(key=lambda x: x[4], reverse=True)

# Convert results to DataFrame
columns = ['voc1_name', 'voc1_concept_id', 'voc2_concept_id', 'voc2_name', 'similarity']
results_df = pd.DataFrame(results, columns=columns)

elapsed_time = (time.time() - start_time) / 60
print(f"Total elapsed time: {elapsed_time:.1f} minutes")

# %%
# Output the results as a Pandas dataframe
df_sorted = results_df.sort_values(by=['voc1_name', 'similarity'], ascending=False)
df_sorted['origin']='TfIDF'
df_sorted.to_csv('final_table'+'_tfiidf.csv', index=False)
df_sorted.head(50)

# %%
df_tfidf=df_sorted

# %% [markdown]
# # Levenshtein Distance

# %%
# !pip install python-Levenshtein

# %%
import Levenshtein as lev

# %%
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: sorted(x))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: x.strip("[]").replace("'", "").split(', '))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: sorted(x))

# %%
voc2_df.head(10)

# %%
start_time = time.time()
results = []

count = 0
num_top_matches = 10  # Указываем количество ближайших совпадений, которые мы хотим сохранить

for voc1_index, voc1_row in voc1_df.iterrows():
    voc1_name = voc1_row['concept_name']
    voc1_concept_id=voc1_row['concept_id']
    voc1_tokens = voc1_row['concept_name_processed']

    min_distances = [float('inf')] * num_top_matches  # Список для хранения наименьших расстояний
    top_matches = [[] for _ in range(num_top_matches)]  # Список для хранения ближайших сочетаний

    for voc2_index, voc2_row in voc2_df.iterrows():
        voc2_concept_id = voc2_row['concept_id']
        voc2_name = voc2_row['concept_name_processed']

        # Calculate Levenshtein distance between voc1 and voc2 concept names
        distance = lev.distance(''.join(voc1_tokens), ''.join(voc2_name))

        # Обновляем ближайшие совпадения, если найдено более близкое совпадение
        for i in range(num_top_matches):
            if distance < min_distances[i]:
                min_distances.insert(i, distance)
                min_distances.pop()
                top_matches.insert(i, (voc2_concept_id, voc2_row['concept_name'], distance))
                top_matches.pop()
                break

    # Сортируем top_matches по возрастанию min_distance перед добавлением в results
    top_matches.sort(key=lambda x: x[2])

    # Добавляем ближайшие совпадения в результаты
    for matches in top_matches:
        if matches:  # Проверяем, что список не пустой
            voc2_concept_id, voc2_name, min_distance = matches
            results.append((voc1_name, voc1_concept_id, voc2_concept_id, voc2_name, min_distance))

    count += 1
    if count % 10 == 0:
        elapsed_time = (time.time() - start_time) / 60
        print(f"Elapsed time: {elapsed_time:.1f} minutes for {count} концептов")

# Convert results to DataFrame
columns = ['voc1_name', 'voc1_concept_id', 'voc2_concept_id', 'voc2_name', 'min_distance']
results_df = pd.DataFrame(results, columns=columns)

elapsed_time = (time.time() - start_time) / 60
print(f"Total elapsed time: {elapsed_time:.1f} minutes")

# %%
# Output the results as a Pandas dataframe
df_sorted = results_df.sort_values(by=['voc1_name', 'min_distance'], ascending=True)
df_sorted['origin']='Levenshtein_distance'
df_sorted.to_csv('final_table'+'_levenshtein.csv', index=False)
df_sorted.head(50)

# %%
df_levenshtein=df_sorted

# %% [markdown]
# # BioWordVec

# %%
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: sorted(x))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: x.strip("[]").replace("'", "").split(', '))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: sorted(x))

# %%
import time
import numpy as np
import gensim
from sklearn.metrics.pairwise import cosine_similarity

# Load the pre-trained word embeddings model
model_path = 'H:/BioWordVec_PubMed_MIMICIII_d200.vec.bin'
word2vec_model = gensim.models.KeyedVectors.load_word2vec_format(model_path, binary=True)
start_time = time.time()

# Функция для векторизации текста с использованием BioWordVec
def vectorize_text(text, model):
    tokens = text.split()
    vectors = [model[token] for token in tokens if token in model]
    if vectors:
        return np.mean(vectors, axis=0)  # Усреднение векторов
    else:
        return np.zeros(model.vector_size)  # Возвращает нулевой вектор, если нет известных слов

# Применение функции к медицинским терминам в обоих наборах данных
voc1_df['voc1_vector'] = voc1_df['concept_name_processed'].apply(lambda x: vectorize_text(' '.join(x), word2vec_model))
voc2_df['voc2_vector'] = voc2_df['concept_name_processed'].apply(lambda x: vectorize_text(' '.join(x), word2vec_model))

# Удаление строк с отсутствующими векторами
voc1_df = voc1_df.dropna(subset=['voc1_vector'])
voc2_df = voc2_df.dropna(subset=['voc2_vector'])

# %%
start_time = time.time()

num_top_matches = 10

v1 = np.vstack(voc1_df['voc1_vector'])
v2 = np.vstack(voc2_df['voc2_vector'])
similarity = cosine_similarity(v1, v2)
tops = (-similarity).argsort()[:, :num_top_matches]

results_df = pd.concat(     # concat (axis = 0) the list of data frames
    [pd.concat( # generate a list of data frames by concatenating (axis = 1) selected rows and cols from voc1 and voc2
        [voc1_df.loc[[i], ['concept_name', 'target_concept_id']].reset_index(drop=True),  # for each target concept from voc_1
         voc2_df.loc[[t], ['concept_id', 'concept_name']].reset_index(drop=True),        # add potential mapping match from voc_2
         pd.Series(similarity[i][t], name='Similarity')], axis= 1)                       # and similarity value
     for i in range(0, len(voc1_df)) for t in tops[i]]                                   # `i` - target vocabulary index, `t` - index in top similarity array
).reset_index(drop=True)

elapsed_time = (time.time() - start_time) / 60
print(f"Total elapsed time: {elapsed_time:.1f} minutes")
# Out:
# Total elapsed time: 1.4 minutes

# %%
# Old working but very slow code

# results = []
# num_top_matches = 10

# for voc1_index, voc1_row in voc1_df.iterrows():
#     voc1_name = voc1_row['concept_name']
#     voc1_vector = voc1_row['voc1_vector']
#     voc1_concept_id = voc1_row['concept_id']

#     similarities = []
#     for voc2_index, voc2_row in voc2_df.iterrows():
#         voc2_name = voc2_row['concept_name']  # Сохраняем concept_id
#         voc2_concept_id = voc2_row['concept_id']
#         voc2_vector = voc2_row['voc2_vector']

#         if voc1_vector is not None and voc2_vector is not None:
#             similarity = cosine_similarity([voc1_vector], [voc2_vector])[0][0]
#             similarities.append((voc2_name, voc2_concept_id, similarity))

#     similarities.sort(key=lambda x: x[2], reverse=True)
#     top_matches = similarities[:num_top_matches]

#     for voc2_name, voc2_concept_id, similarity in top_matches:
#         results.append((voc1_name, voc1_concept_id, voc2_concept_id, voc2_name, similarity))  # Добавляем voc1_index и voc2_name

#     # Счетчик каждых 10 обработанных строк
#     if (voc1_index + 1) % 10 == 0:
#         elapsed_time = (time.time() - start_time) / 60
#         print(f"Elapsed time: {elapsed_time:.1f} minutes for processed {voc1_index + 1} rows")

        
# # Создать DataFrame с результатами
# columns = ['voc1_name', 'voc1_concept_id', 'voc2_concept_id', 'voc2_name', 'similarity']  # Добавляем 'voc1_index'
# results_df = pd.DataFrame(results, columns=columns)

# elapsed_time = (time.time() - start_time) / 60
# print(f"Total elapsed time: {elapsed_time:.1f} minutes")

# %%
results_df.head(50)
# Out:
#                        concept_name  target_concept_id  concept_id  \
# 0                 Excision of hymen            4248130     4183993
# 1                 Excision of hymen            4248130     4029358
# 2                 Excision of hymen            4248130      506989
# 3                 Excision of hymen            4248130      506988
# 4                 Excision of hymen            4248130      507710
# 5                 Excision of hymen            4248130     4125349
# 6                 Excision of hymen            4248130     4087107
# 7                 Excision of hymen            4248130      506957
# 8                 Excision of hymen            4248130     4049783
# 9                 Excision of hymen            4248130     4183993
# 10       OTHER: JVD, RASH, ERYTHEMA             137193    37311082
# 11       OTHER: JVD, RASH, ERYTHEMA             137193     1340326
# 12       OTHER: JVD, RASH, ERYTHEMA             137193    37311082
# 13       OTHER: JVD, RASH, ERYTHEMA             137193     4262179
# 14       OTHER: JVD, RASH, ERYTHEMA             137193     4082588
# 15       OTHER: JVD, RASH, ERYTHEMA             137193     4308009
# 16       OTHER: JVD, RASH, ERYTHEMA             137193     4083795
# 17       OTHER: JVD, RASH, ERYTHEMA             137193     4224056
# 18       OTHER: JVD, RASH, ERYTHEMA             137193      140214
# 19       OTHER: JVD, RASH, ERYTHEMA             137193     4083309
# 20                     HIP FRACTURE           45763653      433856
# 21                     HIP FRACTURE           45763653     4138412
# 22                     HIP FRACTURE           45763653    46270166
# 23                     HIP FRACTURE           45763653    45767041
# 24                     HIP FRACTURE           45763653     4323194
# 25                     HIP FRACTURE           45763653     4323194
# 26                     HIP FRACTURE           45763653      618877
# 27                     HIP FRACTURE           45763653      760691
# 28                     HIP FRACTURE           45763653    45767005
# 29                     HIP FRACTURE           45763653     4138277
# 30                       Osmolality            4237146     4237146
# 31                       Osmolality            4237146     4260822
# 32                       Osmolality            4237146    37392177
# 33                       Osmolality            4237146     4293730
# 34                       Osmolality            4237146     4268330
# 35                       Osmolality            4237146     4103860
# 36                       Osmolality            4237146     4200859
# 37                       Osmolality            4237146      444369
# 38                       Osmolality            4237146    37398646
# 39                       Osmolality            4237146     4193226
# 40  Liver disorder in pregnancy NOS             194699      194699
# 41  Liver disorder in pregnancy NOS             194699      194699
# 42  Liver disorder in pregnancy NOS             194699      196170
# 43  Liver disorder in pregnancy NOS             194699      443292
# 44  Liver disorder in pregnancy NOS             194699      443292
# 45  Liver disorder in pregnancy NOS             194699      196170
# 46  Liver disorder in pregnancy NOS             194699     4239091
# 47  Liver disorder in pregnancy NOS             194699    37396531
# 48  Liver disorder in pregnancy NOS             194699     4173179
# 49  Liver disorder in pregnancy NOS             194699    45757190
#
#                                          concept_name  Similarity
# 0   Excision of uterus and supporting structures (...    0.824244
# 1              Excision of head structure (procedure)    0.819015
# 2   Primary fleur-de-lys abdominoplasty with excis...    0.816473
# 3   Primary fleur-de-lys abdominoplasty with excis...    0.813626
# 4   Primary fleur-de-lys abdominoplasty with excis...    0.812911
# 5     Removal of mole of skin by excision (procedure)    0.810542
# 6             Minor surgery done - excision (finding)    0.810011
# 7   Primary fleur-de-lys abdominoplasty with excis...    0.809283
# 8               Complete excision of anus (procedure)    0.809114
# 9        Excision of uterus and supporting structures    0.808420
# 10                                  Erythematous rash    0.888413
# 11                  Exacerbation of erythematous rash    0.884286
# 12                        Erythematous rash (finding)    0.882330
# 13                               Papular rash of chin    0.854223
# 14                                    Urticarial rash    0.849430
# 15                                     Petechial rash    0.849008
# 16                                 Maculopapular rash    0.848250
# 17                     Nonblanchable erythema of skin    0.845155
# 18                                          Skin rash    0.841377
# 19                                  Morbilliform rash    0.840727
# 20                                    Fracture of hip    1.000000
# 21                                       Hip fracture    1.000000
# 22                     Periprosthetic fracture of hip    0.969177
# 23                       Osteoporotic fracture of hip    0.968549
# 24                           Malunion of hip fracture    0.959984
# 25                        Malunion of fracture of hip    0.959984
# 26                                   Fracture of knee    0.955986
# 27                 Osteoporotic fracture of right hip    0.955048
# 28             Secondary osteoporotic fracture of hip    0.948782
# 29                  Fracture dislocation of hip joint    0.946904
# 30                                         Osmolality    1.000000
# 31                                   Serum osmolality    0.889194
# 32                                   Serum osmolality    0.889194
# 33                                  Plasma osmolality    0.882446
# 34                                         Osmolarity    0.872914
# 35                             Osmolality measurement    0.867927
# 36                             Osmolality disturbance    0.857923
# 37                                    Hyperosmolality    0.854847
# 38                                   Urine osmolality    0.840288
# 39                                   Urine osmolality    0.840288
# 40                        Liver disorder in pregnancy    0.973118
# 41             Liver disorder in pregnancy (disorder)    0.942368
# 42  Liver disorder in pregnancy - delivered (disor...    0.934520
# 43  Liver disorder in pregnancy - not delivered (d...    0.934520
# 44        Liver disorder in pregnancy - not delivered    0.934348
# 45            Liver disorder in pregnancy - delivered    0.934348
# 46          Necrosis of liver of pregnancy (disorder)    0.926300
# 47          Acute fatty liver of pregnancy (disorder)    0.920836
# 48  Perinatal disorders of liver and/or biliary sy...    0.905923
# 49                       Liver disorder in childbirth    0.903951

# %%
# Modification to new variant
new_columns = list(results_df.columns)
new_columns[0] = 'voc1_name'
results_df.columns = new_columns
results_df.rename(columns={
    'target_concept_id': 'voc1_concept_id',
    'concept_id': 'voc2_concept_id',
    'concept_name': 'voc2_name',
    'Similarity': 'similarity'
}, inplace=True)

# Присвойте новый список названий столбцов атрибуту 'columns' DataFrame
results_df['voc1_concept_id']=0
results_df
# Out:
#                                voc1_name  voc1_concept_id  voc2_concept_id  \
# 0                      Excision of hymen                0          4183993
# 1                      Excision of hymen                0          4029358
# 2                      Excision of hymen                0           506989
# 3                      Excision of hymen                0           506988
# 4                      Excision of hymen                0           507710
# ...                                  ...              ...              ...
# 4995  Obstetric umbilical artery Doppler                0         42535610
# 4996  Obstetric umbilical artery Doppler                0         42535610
# 4997  Obstetric umbilical artery Doppler                0         42535610
# 4998  Obstetric umbilical artery Doppler                0          4145534
# 4999  Obstetric umbilical artery Doppler                0         44784445
#
#                                               voc2_name  similarity
# 0     Excision of uterus and supporting structures (...    0.824244
# 1                Excision of head structure (procedure)    0.819015
# 2     Primary fleur-de-lys abdominoplasty with excis...    0.816473
# 3     Primary fleur-de-lys abdominoplasty with excis...    0.813626
# 4     Primary fleur-de-lys abdominoplasty with excis...    0.812911
# ...                                                 ...         ...
# 4995  Doppler ultrasound velocimetry of umbilical ar...    0.933016
# 4996  Doppler ultrasound scan velocimetry of umbilic...    0.916219
# 4997  Doppler ultrasound scan velocimetry of umbilic...    0.914680
# 4998        Doppler ultrasound scan of umbilical artery    0.913540
# 4999  Single artery of fetal umbilical cord on obste...    0.911325
#
# [5000 rows x 5 columns]

# %%
# Output the results as a Pandas dataframe
df_sorted = results_df.sort_values(by=['voc1_name', 'similarity'], ascending=False)
df_sorted['origin']='BioWordVec'
df_sorted.to_csv('final_table'+'_biowordvec.csv', index=False)
df_sorted.head(50)
# Out:
#                                          voc1_name  voc1_concept_id  \
# 2990                                    sigmoidosc                0
# 2991                                    sigmoidosc                0
# 2992                                    sigmoidosc                0
# 2993                                    sigmoidosc                0
# 2994                                    sigmoidosc                0
# 2995                                    sigmoidosc                0
# 2996                                    sigmoidosc                0
# 2997                                    sigmoidosc                0
# 2998                                    sigmoidosc                0
# 2999                                    sigmoidosc                0
# 4260                             right renal stone                0
# 4261                             right renal stone                0
# 4262                             right renal stone                0
# 4263                             right renal stone                0
# 4264                             right renal stone                0
# 4265                             right renal stone                0
# 4266                             right renal stone                0
# 4267                             right renal stone                0
# 4268                             right renal stone                0
# 4269                             right renal stone                0
# 4060                              pulmonary artery                0
# 4061                              pulmonary artery                0
# 4062                              pulmonary artery                0
# 4063                              pulmonary artery                0
# 4064                              pulmonary artery                0
# 4065                              pulmonary artery                0
# 4066                              pulmonary artery                0
# 4067                              pulmonary artery                0
# 4068                              pulmonary artery                0
# 4069                              pulmonary artery                0
# 1510  pancytopenia; toxic bone marrow suppression;                0
# 1511  pancytopenia; toxic bone marrow suppression;                0
# 1512  pancytopenia; toxic bone marrow suppression;                0
# 1513  pancytopenia; toxic bone marrow suppression;                0
# 1514  pancytopenia; toxic bone marrow suppression;                0
# 1515  pancytopenia; toxic bone marrow suppression;                0
# 1516  pancytopenia; toxic bone marrow suppression;                0
# 1517  pancytopenia; toxic bone marrow suppression;                0
# 1518  pancytopenia; toxic bone marrow suppression;                0
# 1519  pancytopenia; toxic bone marrow suppression;                0
# 3640                                    mouth swab                0
# 3641                                    mouth swab                0
# 3642                                    mouth swab                0
# 3643                                    mouth swab                0
# 3644                                    mouth swab                0
# 3645                                    mouth swab                0
# 3646                                    mouth swab                0
# 3647                                    mouth swab                0
# 3648                                    mouth swab                0
# 3649                                    mouth swab                0
#
#       voc2_concept_id                                          voc2_name  \
# 2990         36684768                    Drusen of bilateral optic discs
# 2991          4095324   Human leukocyte antigen A genotype determination
# 2992         35610376                                        Otosyphilis
# 2993          4146361  Failed attempted abortion with electrolyte imb...
# 2994          4228331                     Leucokeratosis nicotina palati
# 2995          4283224         Repair of parasternal diaphragmatic hernia
# 2996         43021066  Aneurysm of patch of right ventricular outflow...
# 2997          4019257              Complete tear, sacrotuberous ligament
# 2998           133645  Burn any degree involving 80-89 percent of bod...
# 2999         42537493          Recurrent cholesteatoma of mastoid cavity
# 4260           201620                                        Renal stone
# 4261          4127717                              Stone in renal pelvis
# 4262          4341799     Open stone operation on kidney or renal pelvis
# 4263         37208260                             Recurrent kidney stone
# 4264          4341799  Open stone operation on kidney or renal pelvis...
# 4265           201620                                       Kidney stone
# 4266           201620                                     Renal calculus
# 4267          4032451                            Calyceal renal calculus
# 4268          4201610  Percutaneous nephrostomy with fragmentation of...
# 4269          4298166  Removal of calculus of renal pelvis through pe...
# 4060          4049408                       Stenting of pulmonary artery
# 4061          4324068                Unifocalization of pulmonary artery
# 4062          4316874                 Retro-oesophageal pulmonary artery
# 4063          4324068                Unifocalisation of pulmonary artery
# 4064          4051944                  Arterioplasty of pulmonary artery
# 4065          4109478                  Collaterals to pulmonary arteries
# 4066          4117127                   Embolisation of pulmonary artery
# 4067          4097984                    Coarctation of pulmonary artery
# 4068          4317288                          Pulmonary artery stenosis
# 4069          4316874                   Retroesophageal pulmonary artery
# 1510          4156433                            Bone marrow suppression
# 1511          4057593                Bone marrow megaloblastic (finding)
# 1512          4117422                               Aplastic bone marrow
# 1513          4058606              Bone marrow suppression - irradiation
# 1514          4219140         Bone marrow granulocytic aplasia (finding)
# 1515          4227088             Drug-induced hypoplasia of bone marrow
# 1516          4056990                 Bone marrow normoblastic (finding)
# 1517          4005793               Decreased bone marrow iron (finding)
# 1518          4047511                     Severe bone marrow hyperplasia
# 1519          4002017                  Absent bone marrow iron (finding)
# 3640          4137105                                    Take mouth swab
# 3641          4210122                                 Taking throat swab
# 3642          4137105                        Take mouth swab (procedure)
# 3643          4208080                                   Taking nose swab
# 3644          4208080                                  Taking nasal swab
# 3645          4056278                        Mouth swab culture positive
# 3646          4195034                              Taking postnasal swab
# 3647          4056529                        Mouth swab culture negative
# 3648          4302951                                   Taking oral swab
# 3649         45769354                  Taking throat swab for gonorrhoea
#
#       similarity      origin
# 2990    0.000000  BioWordVec
# 2991    0.000000  BioWordVec
# 2992    0.000000  BioWordVec
# 2993    0.000000  BioWordVec
# 2994    0.000000  BioWordVec
# 2995    0.000000  BioWordVec
# 2996    0.000000  BioWordVec
# 2997    0.000000  BioWordVec
# 2998    0.000000  BioWordVec
# 2999    0.000000  BioWordVec
# 4260    0.926934  BioWordVec
# 4261    0.896151  BioWordVec
# 4262    0.894615  BioWordVec
# 4263    0.890623  BioWordVec
# 4264    0.880668  BioWordVec
# 4265    0.879246  BioWordVec
# 4266    0.878300  BioWordVec
# 4267    0.876283  BioWordVec
# 4268    0.873930  BioWordVec
# 4269    0.867893  BioWordVec
# 4060    1.000000  BioWordVec
# 4061    0.961087  BioWordVec
# 4062    0.959827  BioWordVec
# 4063    0.955856  BioWordVec
# 4064    0.955108  BioWordVec
# 4065    0.953883  BioWordVec
# 4066    0.951664  BioWordVec
# 4067    0.951440  BioWordVec
# 4068    0.951227  BioWordVec
# 4069    0.950963  BioWordVec
# 1510    0.917426  BioWordVec
# 1511    0.907869  BioWordVec
# 1512    0.901658  BioWordVec
# 1513    0.899455  BioWordVec
# 1514    0.899455  BioWordVec
# 1515    0.898001  BioWordVec
# 1516    0.891510  BioWordVec
# 1517    0.890269  BioWordVec
# 1518    0.890160  BioWordVec
# 1519    0.888701  BioWordVec
# 3640    0.946033  BioWordVec
# 3641    0.907569  BioWordVec
# 3642    0.901157  BioWordVec
# 3643    0.888028  BioWordVec
# 3644    0.877697  BioWordVec
# 3645    0.876644  BioWordVec
# 3646    0.874967  BioWordVec
# 3647    0.871838  BioWordVec
# 3648    0.870818  BioWordVec
# 3649    0.870710  BioWordVec

# %%
df_biowordvec=df_sorted

# %% [markdown]
# # Final merge tables and remove duplicates

# %%
import datetime
current_datetime = datetime.datetime.now()
current_date = current_datetime.date()

# %%
# Объединить таблицы, устранить дублирующие строки с одинаковыми парами сорс-код и potential_concept_id
table_name = 'combined_table_'+str(current_date)+'.csv'
df_exp = pd.concat([df_tfidf, df_biowordvec, df_levenshtein])
df_exp = df_exp.sort_values(by=['voc1_name'])
df_exp.to_csv(table_name)

# %%
# combined_df=pd.concat([df_tfidf, df_biowordvec, df_levenshtein])                                  
# combined_df['question'] = 'Pick the best semantic match for '
# combined_df = combined_df[['question'] + [col for col in combined_df.columns if col != 'question']]
# combined_df.rename(columns={'voc1_name': 'source_code_description', 'voc2_concept_id': 'potential_target_concept_id'}, inplace=True)
# combined_df = combined_df.sort_values(by=['source_code_description', 'potential_target_concept_id'])
# unique_combined_df = combined_df.drop_duplicates(subset=['source_code_description', 'potential_target_concept_id'])
# unique_combined_df.to_csv('final_table_gpt.csv', index=False)
# unique_combined_df.head(50)

# %%
# unique_combined_df = unique_combined_df[['question', 'source_code_description', 'potential_target_concept_id']]
# unique_combined_df['chatgptreply']=''
# unique_combined_df['target_concept_id']=0
# unique_combined_df.head(50)

# %%
# login="dev_test5"
# passw = "7hGg365$%fhhTfr$dJ"
# engine = create_engine('postgresql://{}:{}@ovh07.odysseusinc.com:5555/postgres'.format(login, passw))
# table_name = 'chatgpt_table_'+str(current_date)
# unique_combined_df.to_sql(table_name, engine, if_exists='replace', index=False)
# print(f'Import {table_name} was sucessful!')

# %%
# Объединить кусочки таблиц (при необходимости)
import pandas as pd
df1 = pd.read_csv('combined_table_1.csv')
df2 = pd.read_csv('combined_table_2.csv')
df3 = pd.read_csv('combined_table_3.csv')
df = pd.concat([df1, df2, df3])
df = df.sort_values(by=['voc1_name', 'voc2_concept_id'])
df = df.drop_duplicates(subset=['voc1_name', 'voc2_concept_id'])
df.to_csv('combined_table_final_091023.csv', index=False)
